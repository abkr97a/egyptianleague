# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Egyptian Players 2000 to 2024.csv')
df.head()
# Out:
#    Season   Team Name  Club ID     Player_Name  Player ID  Number  \
# 0    2000  Goldi Club    51214  Nader El-Sayed      39553     NaN
# 1    2000  Goldi Club    51214     Hassan Nasr     785894     NaN
# 2    2000  Goldi Club    51214  Amr Abdelsalam     597438     NaN
# 3    2000  Goldi Club    51214    Adly Mahgoub     787505     NaN
# 4    2000  Goldi Club    51214       Amr Abdou     105873     NaN
#
#       Position   Age  InSquad  Matches    Min  Goals  Assists  Yellow_Cards  \
# 0   Goalkeeper  27.0      NaN      NaN    NaN    NaN      NaN           NaN
# 1   Goalkeeper  34.0      1.0      NaN    NaN    NaN      NaN           NaN
# 2   Goalkeeper  27.0      5.0      5.0  450.0    NaN      NaN           NaN
# 3   Goalkeeper   NaN      1.0      1.0   90.0    NaN      NaN           NaN
# 4  Centre-Back  24.0      4.0      3.0  270.0    NaN      NaN           NaN
#
#    Red_Cards Nationality
# 0        0.0       Egypt
# 1        0.0       Egypt
# 2        0.0       Egypt
# ...

# %%
df_unique = df[['Player ID', 'Nationality', 'Player_Name', 'Position']]
df_unique.head()
# Out:
#    Player ID Nationality     Player_Name     Position
# 0      39553       Egypt  Nader El-Sayed   Goalkeeper
# 1     785894       Egypt     Hassan Nasr   Goalkeeper
# 2     597438       Egypt  Amr Abdelsalam   Goalkeeper
# 3     787505       Egypt    Adly Mahgoub   Goalkeeper
# 4     105873       Egypt       Amr Abdou  Centre-Back

# %%
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20601 entries, 0 to 20600
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player ID    20601 non-null  int64
#  1   Nationality  20601 non-null  object
#  2   Player_Name  20601 non-null  object
#  3   Position     20601 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 643.9+ KB

# %%
df_unique.drop_duplicates(inplace=True)
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3902 entries, 0 to 20569
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player ID    3902 non-null   int64
#  1   Nationality  3902 non-null   object
#  2   Player_Name  3902 non-null   object
#  3   Position     3902 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 152.4+ KB
# <ipython-input-6-8c79c5bd283d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique.drop_duplicates(inplace=True)

# %%
df_unique.to_csv('Unique_Players.csv', index=False)
